# %%
#Biplov Maharjan
#week 1 worksheet

# %%
#task 1 

time_data = [
    (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
    (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
    (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
    (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
    (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]

low = []
moderate = []
high = []

for study in time_data:
    if study[0] < 3:
        low.append(study[0])
    elif 3 <= study[0] <=5:
        moderate.append(study[0])
    else:
        high.append(study[0])

print("low study hours:",low)
print("moderate study hours:",moderate)
print("high study hourse:",high)
# Out:
# low study hours: [2.5, 1.5, 2.0, 2.5]
# moderate study hours: [3.5, 5.0, 4.0, 3.0, 4.5, 3.0, 4.0, 5.0, 3.5]
# high study hourse: [5.5, 6.0]

# %%
#task 2

low_study_time = len(low)
moderate_study_time = len(moderate)
high_study_time = len(high)

print(f"Low study time: {low_study_time}")
print(f"moderate study time: {moderate_study_time}")
print(f"high study time: {high_study_time}")
# Out:
# Low study time: 4
# moderate study time: 9
# high study time: 2

# %%
#task 3

study_minute = []
for study in time_data:
    minute = study[0]*60
    study_minute.append(minute)
print(f"The converted minute are: {study_minute}")
# Out:
# The converted minute are: [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %%
#task 4

study_hours = []
entertainment_hours = []
sleep_hours = []
sum_study = 0
sum_entertainment = 0
sum_sleep = 0
for study in time_data:
    if study[0]:
        study_hours.append(study[0])
    if study[1]:
        entertainment_hours.append(study[1])
    if study[2]:
        sleep_hours.append(study[2]) 
print(f"Study hours = {study_hours}")
print(f"Entertainment hours = {entertainment_hours}")
print(f"Sleep hours = {sleep_hours}")
for i in sleep_hours:
        sum_study+=i  
for j in entertainment_hours:
    sum_entertainment+=i
for k in sleep_hours:
    sum_sleep+=i
print(f"Average study hours is {sum_study/2}")
print(f"Average entertainment hours is {sum_entertainment/2}")
print(f"Average sleep hours is {sum_sleep/2}")
# Out:
# Study hours = [3.5, 5.0, 2.5, 4.0, 1.5, 3.0, 5.5, 2.0, 4.5, 3.0, 6.0, 2.5, 4.0, 5.0, 3.5]
# Entertainment hours = [2.0, 1.5, 3.0, 2.0, 4.5, 2.5, 1.0, 3.5, 2.0, 3.0, 1.5, 4.0, 2.5, 2.0, 2.5]
# Sleep hours = [7.0, 6.5, 8.0, 6.0, 9.0, 7.5, 6.0, 8.5, 7.0, 7.5, 6.0, 8.0, 7.0, 6.5, 7.0]
# Average study hours is 53.75
# Average entertainment hours is 52.5
# Average sleep hours is 52.5

# %%
#task 5
import matplotlib.pyplot as plt

plt.scatter(study_hours, sleep_hours, color="red")
plt.xlabel("study hours")
plt.ylabel("sleep hours")
plt.title("study vs sleep pattern")
# Out:
# Text(0.5, 1.0, 'study vs sleep pattern')

# %%
#8.1
#task1

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
def sum_nested_list(nested_list):
    total = 0
    for item in nested_list:
       if isinstance(item, list): 
           total+=sum_nested_list(item)
       else:
           total+=item
    return total
sum_nested_list(nested_list)
# Out:
# 36

# %%
#task2
def generate_permutations(s):
    if len(s)==1:
        return s
    permutations = []
    for i in range (len(s)):
        chr = s[i]
        remaining_chr = s[:i] + s[i+1:]
    
        for p in generate_permutations(remaining_chr):
            permutations.append(chr + p)
    return permutations

print(generate_permutations('abc'))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %%
#task3

directory = {
"file1.txt": 200,
"file2.txt": 300,
"subdir1": {
"file3.txt": 400,
"file4.txt": 100
},
"subdir2": {
"subsubdir1": {
"file5.txt": 250
},
"file6.txt": 150
}
}
def calculate_directory_size(directory):
    total = 0
    for kb in directory.values():
       if isinstance(kb, dict): 
           total+=calculate_directory_size(kb)
       else:
           total+=kb
    return total
print(calculate_directory_size(directory))
# Out:
# 1400

# %%
8.2
#task1
def min_coins(coins, amount):
    dp = [(float('inf'))] * (amount + 1)
    dp[0] = 0

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)
    if dp[amount] != float('inf'):
        return dp[amount]
    else:
        return -1
print(min_coins([5,5,1],11 ))
# Out:
# 3

# %%
#task2
def longest_common_subsequence(s1, s2):
    n, m = len(s1), len(s2)
    dp = [[0] * (m + 1) for _ in range(n + 1)]
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
    
    return dp[n][m]

print(longest_common_subsequence("abcde", "ace"))
# Out:
# 3

# %%
#task3
def knapsack(weights, values, capacity):
    n = len(weights)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]
    for i in range(1, n + 1):
        w = weights[i - 1]
        v = values[i - 1]

        for c in range(1, capacity + 1):
            if w <= c:
                dp[i][c] = max(v + dp[i - 1][c - w], dp[i - 1][c])
            else:
                dp[i][c] = dp[i - 1][c]

    return dp[n][capacity]
weights = [1, 3, 4, 5]
values =  [1, 4, 5, 7]
capacity = 7

print(knapsack(weights, values, capacity))
# Out:
# 9
